# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import urllib.request as request
import json

API_KEY = "<YOUR API KEY>"
URL = f"https://www.wanikani.com/api/user/{API_KEY}"

# %%
def api_call(resource, optional_argument="", info_only=True):
    req = request.urlopen(f"{URL}/{resource}/{optional_argument}")
    data = json.loads(req.read())
    
    if info_only:
        return data["requested_information"]
    else:
        return data

# %%
def levels(m, n=None):
    if not n:
        n = m
        m = 1
    return str.join(",", [str(i) for i in range(m, n + 1)])
    
all_levels = levels(60)

# %%
radicals = pd.DataFrame(api_call("radicals", levels))[["level", "character", "meaning"]]
radicals
# Out:
#      level character       meaning
# 0        1         一        ground
# 1        1         ハ          fins
# 2        1         丶          drop
# 3        1         七         seven
# 4        1         丿         slide
# 5        1         亅          barb
# 6        1         亠           lid
# 7        1         人        person
# 8        1         二           two
# 9        1         入         enter
# 10       1         九          nine
# 11       1         力         power
# 12       1         ト           toe
# 13       1         勹     enclosure
# 14       1         十         cross
# 15       1         口         mouth
# 16       1         大           big
# 17       1         女         woman
# 18       1         山      mountain
# 19       1         川         river
# 20       1         日           sun
# 21       1         工  construction
# 22       1         木          tree
# 23       1      None           gun
# 24       1      None          leaf
# 25       1      None         stick
# 26       2         又         stool
# 27       2         土         grave
# 28       2         刀         sword
# 29       2         ナ       narwhal
# ..     ...       ...           ...
# 195      9      None         train
# 196      9         介           hut
# 197      9         史       history
# 198      9         癶          tent
# 199      9         阝       butcher
# 200      9         咅         clown
# 201      9         辛         spicy
# 202      9         重         heavy
# 203      9         反         devil
# 204      9         聿         brush
# 205      9         台       machine
# 206      9         覀    helicopter
# 207      9      None          hick
# 208      9      None         cleat
# 209      9      None          pope
# 210     10         圣     tombstone
# 211     10         辰      superman
# 212     10         酉       alcohol
# 213     10         豆         beans
# 214     10         丙      dynamite
# 215     10         頁       geoduck
# 216     10         各          kiss
# 217     10         曲         music
# 218     10         疒          sick
# 219     10         乃        stairs
# 220     10         束           ent
# 221     10         隹        turkey
# 222     10         失         fault
# 223     10         売          sell
# 224     10      None       chinese
#
# [225 rows x 3 columns]

# %%
kanji = pd.DataFrame(api_call("kanji", all_levels))[["level", "character", "kunyomi", "onyomi", "nanori", "important_reading", "meaning"]]
kanji
# Out:
#       level character         kunyomi     onyomi nanori important_reading  \
# 0        30         背           せ, そむ         はい   None            onyomi
# 1        57         閲              けみ         えつ   None            onyomi
# 2        57         鼓             つづみ          こ   None            onyomi
# 3        57         紺            None         こん   None            onyomi
# 4         9         度              たび      ど, たく   None            onyomi
# 5         3         生  い, なま, う, は, き    せい, しょう   None            onyomi
# 6        60         狐             きつね          こ   None           kunyomi
# 7        60         倹       つづまやか, つま         けん   None            onyomi
# 8        60         蛮             えびす         ばん   None            onyomi
# 9        60         妄              みだ     もう, ぼう   None            onyomi
# 10       60         藻               も         そう   None            onyomi
# 11       60         漸         ようや, やや         ぜん   None           kunyomi
# 12       60         泌            None      ひ, ひつ   None            onyomi
# 13       60         囚              とら        しゅう   None            onyomi
# 14       60         某      それがし, なにがし         ぼう   None            onyomi
# 15       60         矯               た        きょう   None            onyomi
# 16       60         罷               や          ひ   None            onyomi
# 17       60         慕              した          ぼ   None            onyomi
# 18       60         婿              むこ         せい   None           kunyomi
# 19       60         桟            かけはし     さん, せん   None            onyomi
# 20       60         劾            None         がい   None            onyomi
# 21       60         煩        うるさ, わずら     はん, ぼん   None            onyomi
# 22       60         殉            None        じゅん   None            onyomi
# 23       60         升              ます        しょう   None           kunyomi
# 24       60         醜         しこ, みにく        しゅう   None            onyomi
# 25       60         湧               わ  ゆう, ゆ, よう   None            onyomi
# 26       60         謹             つつし         きん   None            onyomi
# 27       60         廉            None         れん   None            onyomi
# 28       60         渓        たに, たにがわ         けい   None            onyomi
# 29       60         拷            None         ごう   None            onyomi
# ...     ...       ...             ...        ...    ...               ...
# 1997      3         外          そと, はず         がい   None            onyomi
# 1998      3         台            None     だい, たい   None            onyomi
# 1999      5         売               う         ばい   None           kunyomi
# 2000      5         声              こえ         せい   None           kunyomi
# 2001      5         図           え, はか       ず, と   None            onyomi
# 2002      5         作              つく      さく, さ   None            onyomi
# 2003      5         体             からだ         たい   None            onyomi
# 2004      5         何          なに, なん          か   None           kunyomi
# 2005      5         西              にし     せい, さい   None            onyomi
# 2006      5         行       い, おこな, ゆ    こう, ぎょう   None            onyomi
# 2007      5         色              いろ    しき, しょく   None           kunyomi
# 2008      5         自            None       じ, し   None            onyomi
# 2009      5         肉            None         にく   None            onyomi
# 2010      5         考             かんが         こう   None           kunyomi
# 2011      5         羽           はね, は          う   None           kunyomi
# 2012      5         米              こめ     べい, まい   None            onyomi
# 2013      5         池              いけ          ち   None           kunyomi
# 2014      5         毎              ごと         まい   None            onyomi
# 2015      5         当               あ         とう   None            onyomi
# 2016      5         多              おお          た   None            onyomi
# 2017      5         回              まわ         かい   None            onyomi
# 2018      5         同              おな         どう   None            onyomi
# 2019      5         光         ひかり, ひか         こう   None            onyomi
# 2020      5         会               あ         かい   None            onyomi
# 2021      5         交        まじ, ま, か         こう   None            onyomi
# 2022      4         仕              つか          し   None            onyomi
# 2023      4         不            None          ふ   None            onyomi
# 2024      4         車             くるま         しゃ   None            onyomi
# 2025      4         足           あし, た         そく   None            onyomi
# 2026      4         赤              あか         せき   None           kunyomi
#
#                              meaning
# 0                       back, height
# 1                         inspection
# 2                               beat
# 3                    navy, dark blue
# 4                degrees, occurrence
# 5                               life
# 6                                fox
# 7            thrifty, frugal, thrift
# 8                          barbarian
# 9                           reckless
# 10                           seaweed
# 11               gradually, steadily
# 12                           secrete
# 13                          criminal
# 14         certain, one, that person
# 15               correct, straighten
# 16                       quit, leave
# 17                  yearn for, adore
# 18                             groom
# 19                       jetty, pier
# 20                           censure
# 21                   annoy, annoying
# 22                            martyr
# 23                     grid, measure
# 24                              ugly
# 25                        well, boil
# 26                  humble, discreet
# 27                           bargain
# 28                            valley
# 29                           torture
# ...                              ...
# 1997                         outside
# 1998                         machine
# 1999                            sell
# 2000                           voice
# 2001                         diagram
# 2002                            make
# 2003                            body
# 2004                            what
# 2005                            west
# 2006                              go
# 2007                   color, colour
# 2008                            self
# 2009                            meat
# 2010                 think, consider
# 2011  feather, feathers, wing, wings
# 2012                   rice, america
# 2013                            pond
# 2014                           every
# 2015         correct, right, success
# 2016             many, much, lots of
# 2017                  times, revolve
# 2018                            same
# 2019                 sunlight, light
# 2020                            meet
# 2021                             mix
# 2022                       doing, do
# 2023                             not
# 2024                             car
# 2025           foot, leg, sufficient
# 2026                             red
#
# [2027 rows x 7 columns]

# %%
vocabulary = pd.DataFrame(api_call("vocabulary", all_levels))[["level", "character", "kana", "meaning"]]
vocabulary
# Out:
#       level character          kana  \
# 0         5        下町          したまち
# 1         4         竹            たけ
# 2         4       竹の子          たけのこ
# 3         4         虫            むし
# 4         6        足す            たす
# 5         6      足りない          たりない
# 6         4        平気           へいき
# 7         4        平ら           たいら
# 8         4        平日          へいじつ
# 9         4        お礼           おれい
# 10        5        毛糸           けいと
# 11        6       大文字          おおもじ
# 12        4        名字          みょうじ
# 13        4        太字           ふとじ
# 14        4         花            はな
# 15        4        休日         きゅうじつ
# 16        4        休む           やすむ
# 17        4        休み           やすみ
# 18        4        休止          きゅうし
# 19        6       冬休み         ふゆやすみ
# 20        4      赤ちゃん         あかちゃん
# 21        4         赤            あか
# 22        4        写る           うつる
# 23        4        花見           はなみ
# 24        4      見分ける          みわける
# 25        4        見方           みかた
# 26        4       見せる           みせる
# 27        4        月見           つきみ
# 28        4        見る            みる
# 29        4         他            ほか
# ...     ...       ...           ...
# 6257     41        鉱業         こうぎょう
# 6258     55         栓            せん
# 6259     10       終わる           おわる
# 6260     35     盛り上げる         もりあげる
# 6261     26        獣類         じゅうるい
# 6262     19       無意識          むいしき
# 6263     17        干天          かんてん
# 6264     27        悩み           なやみ
# 6265     26        象徴        しょうちょう
# 6266     40        近隣          きんりん
# 6267     16        字典           じてん
# 6268     30       詳しい          くわしい
# 6269     33       似合う           にあう
# 6270     35        獄内          ごくない
# 6271     56      呉越同舟      ごえつどうしゅう
# 6272     12         祭           まつり
# 6273     20        人達          ひとたち
# 6274     32       迎える          むかえる
# 6275     17       愛国心        あいこくしん
# 6276     26       間違い          まちがい
# 6277     52        恒星          こうせい
# 6278     15        昨日     きのう, さくじつ
# 6279     49       奨学金       しょうがくきん
# 6280     53        悲惨           ひさん
# 6281     35         剣            けん
# 6282     46        阻止            そし
# 6283     38       奥深い  おくぶかい, おくふかい
# 6284     12         根             ね
# 6285     54       最優遇        さいゆうぐう
# 6286     19        数詞           すうし
#
#                                                 meaning
# 0                                 downtown, backstreets
# 1                                                bamboo
# 2                         bamboo shoots, bamboo sprouts
# 3                                           bug, insect
# 4                                                to add
# 5     not enough, to not be sufficient, to not be en...
# 6                           calm, cool, all right, okay
# 7                                                  flat
# 8                                              weekdays
# 9                                     thanks, gratitude
# 10                                      wool yarn, yarn
# 11    capital letters, uppercase letters, capital le...
# 12                      surname, last name, family name
# 13    bold letter, bold, bold character, bold text, ...
# 14                                               flower
# 15                                              holiday
# 16                                              to rest
# 17                       rest, break, vacation, holiday
# 18                                   pause, rest, break
# 19        winter holiday, winter break, winter vacation
# 20                                                 baby
# 21                                                  red
# 22                                   to be photographed
# 23    viewing cherry blossoms, sakura viewing, cherr...
# 24      to distinguish, to tell apart, to differentiate
# 25    way of seeing, point of view, perspective, vie...
# 26                                              to show
# 27                                         moon viewing
# 28                                      to see, to look
# 29                                                other
# ...                                                 ...
# 6257                                    mining industry
# 6258                                cork, stopper, plug
# 6259                                  to end, to finish
# 6260                             to heap up, to pile up
# 6261                                    beasts, animals
# 6262        unconsciousness, unconsciously, involuntary
# 6263                               dry weather, drought
# 6264                 a worry, worry, a trouble, trouble
# 6265                                             symbol
# 6266                                       neighborhood
# 6267             character dictionary, kanji dictionary
# 6268                                   detailed, expert
# 6269                                  to suit, to match
# 6270                                          in prison
# 6271  bitter enemies in the same boat, classic rival...
# 6272                                           festival
# 6273                                             people
# 6274                to pick someone up, to meet someone
# 6275                                         patriotism
# 6276                                 a mistake, mistake
# 6277                                               star
# 6278                                          yesterday
# 6279                               scholarship, stipend
# 6280   disastrous, tragic, miserable, wretched, pitiful
# 6281            sword, sabre, blade, double edged sword
# 6282                            obstruction, hinderance
# 6283                                     profound, deep
# 6284                                               root
# 6285  most favorable treatment, most favourable trea...
# 6286                               numeral, number word
#
# [6287 rows x 4 columns]

# %%
def strutify(words, hyphen=True):
    return str.join(", ", [r"\strut " + hyphenate(w) for w in words.split(", ")]) + " \strut"

def hyphenate(word):
    from hyphenate import hyphenate_word
    return str.join(r"\-", hyphenate_word(word))

def format_kanji(row):
    import romkan
    kanji = row.character
    
    if row.important_reading == "onyomi":
        reading = strutify(romkan.to_katakana(romkan.to_roma(row.onyomi)))
    elif row.important_reading == "kunyomi":
        reading = strutify(row.kunyomi)
    else:
        reading = strutify(row.nanori)
        
    meaning = strutify(row.meaning)
    return rf"\kanji{{{kanji}}}{{{reading}}}{{{meaning}}}"

# %%
for level in range(1, 10):
    print(rf"\section*{{Level {level}}}")
    print(r"\begin{center}")
    print(str.join("\n", [format_kanji(row) for row in kanji.query(f"level == {level}").itertuples()]))
    print(r"\end{center}")
# Out:
# \section*{Level 1}
# \begin{center}
# \kanji{工}{\strut コウ, \strut ク \strut}{\strut con\-struc\-tion, \strut in\-dus\-try \strut}
# \kanji{川}{\strut かわ \strut}{\strut riv\-er \strut}
# \kanji{山}{\strut サン \strut}{\strut moun\-tain \strut}
# \kanji{女}{\strut ジョ \strut}{\strut woman \strut}
# \kanji{大}{\strut タイ, \strut ダイ \strut}{\strut big, \strut large \strut}
# \kanji{口}{\strut コウ, \strut ク \strut}{\strut mouth \strut}
# \kanji{下}{\strut カ, \strut ゲ \strut}{\strut be\-low, \strut down, \strut un\-der, \strut be\-neath \strut}
# \kanji{上}{\strut ジョウ \strut}{\strut above, \strut up, \strut over \strut}
# \kanji{三}{\strut サン \strut}{\strut three \strut}
# \kanji{十}{\strut ジュウ \strut}{\strut ten \strut}
# \kanji{力}{\strut リョク, \strut リキ \strut}{\strut pow\-er, \strut strength \strut}
# \kanji{八}{\strut ハチ \strut}{\strut eight \strut}
# \kanji{入}{\strut ニュウ \strut}{\strut en\-ter \strut}
# \kanji{人}{\strut ニン, \strut ジン \strut}{\strut per\-son \strut}
# \kanji{七}{\strut シチ \strut}{\strut sev\-en \strut}
# \kanji{九}{\strut ク, \strut キュウ \strut}{\strut nine \strut}
# \kanji{二}{\strut ニ \strut}{\strut two \strut}
# \kanji{一}{\strut イチ \strut}{\strut one \strut}
# \end{center}
# \section*{Level 2}
# \begin{center}
# \kanji{々}{\strut のま \strut}{\strut re\-peater, \strut rep\-e\-ti\-tion, \strut redu\-pli\-ca\-tion, \strut it\-er\-a\-tion \-mark \strut}
# \kanji{水}{\strut スイ \strut}{\strut wa\-ter \strut}
# \kanji{木}{\strut モク \strut}{\strut tree, \strut wood \strut}
# \kanji{月}{\strut ゲツ, \strut ガツ \strut}{\strut moon, \strut month \strut}
# \kanji{日}{\strut ニチ, \strut ジツ \strut}{\strut sun, \strut day \strut}
# \kanji{文}{\strut ブン, \strut モン \strut}{\strut writ\-ing, \strut sen\-tence \strut}
# \kanji{手}{\strut て \strut}{\strut hand \strut}
# \kanji{天}{\strut テン \strut}{\strut heav\-en \strut}
# \kanji{円}{\strut エン \strut}{\strut yen, \strut round, \strut cir\-cle \strut}
# \kanji{六}{\strut ロク \strut}{\strut six \strut}
# \kanji{五}{\strut ゴ \strut}{\strut five \strut}
# \kanji{中}{\strut チュウ \strut}{\strut mid\-dle, \strut in, \strut in\-side, \strut cen\-ter \strut}
# \kanji{才}{\strut サイ \strut}{\strut ge\-nius \strut}
# \kanji{丸}{\strut まる \strut}{\strut cir\-cle, \strut cir\-cu\-lar, \strut round \strut}
# \kanji{又}{\strut また \strut}{\strut again \strut}
# \kanji{了}{\strut リョウ \strut}{\strut fin\-ish, \strut com\-plete, \strut end \strut}
# \kanji{丁}{\strut チョウ, \strut テイ \strut}{\strut street, \strut ward \strut}
# \kanji{小}{\strut ショウ \strut}{\strut small, \strut lit\-tle \strut}
# \kanji{子}{\strut シ, \strut ス \strut}{\strut child, \strut kid \strut}
# \kanji{夕}{\strut ゆう \strut}{\strut evening \strut}
# \kanji{千}{\strut セン \strut}{\strut thou\-sand \strut}
# \kanji{土}{\strut ド, \strut ト \strut}{\strut soil, \strut earth, \strut ground, \strut dirt \strut}
# \kanji{刀}{\strut トウ \strut}{\strut sword, \strut katana \strut}
# \kanji{立}{\strut リツ \strut}{\strut stand \strut}
# \kanji{石}{\strut いし \strut}{\strut stone \strut}
# \kanji{目}{\strut め \strut}{\strut eye \strut}
# \kanji{白}{\strut ハク \strut}{\strut white \strut}
# \kanji{田}{\strut た \strut}{\strut rice \-pad\-dy, \strut rice \-field, \strut field \strut}
# \kanji{玉}{\strut たま \strut}{\strut ball \strut}
# \kanji{正}{\strut セイ, \strut ショウ \strut}{\strut cor\-rect \strut}
# \kanji{本}{\strut ホン \strut}{\strut book, \strut ori\-gin, \strut real, \strut main \strut}
# \kanji{左}{\strut ひだり \strut}{\strut left \strut}
# \kanji{四}{\strut よん, \strut よ \strut}{\strut four \strut}
# \kanji{右}{\strut みぎ \strut}{\strut right \strut}
# \kanji{出}{\strut シュツ \strut}{\strut exit \strut}
# \kanji{王}{\strut オウ \strut}{\strut king \strut}
# \kanji{犬}{\strut いぬ \strut}{\strut dog \strut}
# \kanji{火}{\strut カ \strut}{\strut fire \strut}
# \end{center}
# \section*{Level 3}
# \begin{center}
# \kanji{生}{\strut セイ, \strut ショウ \strut}{\strut life \strut}
# \kanji{古}{\strut コ \strut}{\strut old \strut}
# \kanji{半}{\strut ハン \strut}{\strut half \strut}
# \kanji{北}{\strut ホク \strut}{\strut north \strut}
# \kanji{冬}{\strut ふゆ \strut}{\strut win\-ter \strut}
# \kanji{兄}{\strut あに \strut}{\strut old\-er broth\-er, \strut big broth\-er, \strut el\-der broth\-er \strut}
# \kanji{止}{\strut シ \strut}{\strut stop \strut}
# \kanji{毛}{\strut モウ \strut}{\strut fur, \strut hair \strut}
# \kanji{父}{\strut ちち \strut}{\strut fa\-ther, \strut dad \strut}
# \kanji{牛}{\strut ギュウ \strut}{\strut cow \strut}
# \kanji{方}{\strut かた \strut}{\strut di\-rec\-tion, \strut way \strut}
# \kanji{戸}{\strut と \strut}{\strut door \strut}
# \kanji{心}{\strut シン \strut}{\strut heart \strut}
# \kanji{引}{\strut ひ \strut}{\strut pull \strut}
# \kanji{少}{\strut ショウ \strut}{\strut few, \strut a lit\-tle \strut}
# \kanji{太}{\strut タイ, \strut タ \strut}{\strut fat \strut}
# \kanji{友}{\strut ユウ \strut}{\strut friend \strut}
# \kanji{午}{\strut ゴ \strut}{\strut noon \strut}
# \kanji{切}{\strut セツ \strut}{\strut cut \strut}
# \kanji{分}{\strut ブン, \strut フン, \strut ブ \strut}{\strut part, \strut minute, \strut sep\-a\-rate, \strut un\-der\-stand \strut}
# \kanji{内}{\strut ナイ \strut}{\strut in\-side, \strut with\-in \strut}
# \kanji{公}{\strut コウ \strut}{\strut pub\-lic \strut}
# \kanji{元}{\strut ゲン, \strut ガン \strut}{\strut ori\-gin \strut}
# \kanji{今}{\strut コン \strut}{\strut now \strut}
# \kanji{久}{\strut ひさ \strut}{\strut long \-time \strut}
# \kanji{万}{\strut マン, \strut バン \strut}{\strut ten t\-hou\-sand \strut}
# \kanji{矢}{\strut や \strut}{\strut ar\-row \strut}
# \kanji{用}{\strut ヨウ \strut}{\strut task, \strut use \strut}
# \kanji{母}{\strut はは \strut}{\strut moth\-er, \strut mom, \strut mum \strut}
# \kanji{広}{\strut ひろ \strut}{\strut wide \strut}
# \kanji{市}{\strut シ \strut}{\strut city \strut}
# \kanji{外}{\strut ガイ \strut}{\strut out\-side \strut}
# \kanji{台}{\strut ダイ, \strut タイ \strut}{\strut ma\-chine \strut}
# \end{center}
# \section*{Level 4}
# \begin{center}
# \kanji{貝}{\strut かい \strut}{\strut shell\-fish, \strut shell, \strut clam \strut}
# \kanji{見}{\strut み \strut}{\strut see \strut}
# \kanji{花}{\strut はな \strut}{\strut flower \strut}
# \kanji{町}{\strut チョウ \strut}{\strut town \strut}
# \kanji{男}{\strut ダン \strut}{\strut man \strut}
# \kanji{村}{\strut むら \strut}{\strut vil\-lage \strut}
# \kanji{虫}{\strut むし \strut}{\strut in\-sect, \strut bug \strut}
# \kanji{耳}{\strut みみ \strut}{\strut ear \strut}
# \kanji{糸}{\strut いと \strut}{\strut thread \strut}
# \kanji{竹}{\strut たけ \strut}{\strut bam\-boo \strut}
# \kanji{百}{\strut ヒャク \strut}{\strut hun\-dred \strut}
# \kanji{気}{\strut キ, \strut ケ \strut}{\strut en\-er\-gy, \strut spir\-it \strut}
# \kanji{早}{\strut ソウ \strut}{\strut ear\-ly, \strut fast, \strut quick \strut}
# \kanji{年}{\strut ネン \strut}{\strut year \strut}
# \kanji{字}{\strut ジ \strut}{\strut let\-ter, \strut char\-ac\-ter, \strut sym\-bol \strut}
# \kanji{名}{\strut メイ, \strut ミョウ \strut}{\strut name, \strut fa\-mous \strut}
# \kanji{先}{\strut セン \strut}{\strut pre\-vi\-ous, \strut ahead, \strut past, \strut for\-mer \strut}
# \kanji{休}{\strut キュウ \strut}{\strut rest \strut}
# \kanji{礼}{\strut レイ \strut}{\strut thanks \strut}
# \kanji{皿}{\strut さら \strut}{\strut plate, \strut dish \strut}
# \kanji{皮}{\strut かわ \strut}{\strut skin \strut}
# \kanji{申}{\strut もう \strut}{\strut say humbly, \strut say, \strut humbly say \strut}
# \kanji{氷}{\strut こおり \strut}{\strut ice \strut}
# \kanji{打}{\strut う, \strut ぶ \strut}{\strut hit \strut}
# \kanji{平}{\strut ヘイ, \strut ヒョウ, \strut ビョウ \strut}{\strut flat, \strut peace \strut}
# \kanji{央}{\strut オウ \strut}{\strut cen\-ter, \strut cen\-tral, \strut cen\-tre \strut}
# \kanji{号}{\strut ゴウ \strut}{\strut num\-ber \strut}
# \kanji{去}{\strut キョ, \strut コ \strut}{\strut past \strut}
# \kanji{写}{\strut シャ \strut}{\strut copy \strut}
# \kanji{代}{\strut ダイ \strut}{\strut sub\-sti\-tute, \strut re\-place, \strut pe\-ri\-od, \strut age \strut}
# \kanji{他}{\strut タ \strut}{\strut oth\-er \strut}
# \kanji{主}{\strut シュ \strut}{\strut mas\-ter \strut}
# \kanji{世}{\strut セ, \strut セイ \strut}{\strut gen\-er\-a\-tion, \strut world, \strut so\-ci\-ety \strut}
# \kanji{仕}{\strut シ \strut}{\strut do\-ing, \strut do \strut}
# \kanji{不}{\strut フ \strut}{\strut not \strut}
# \kanji{車}{\strut シャ \strut}{\strut car \strut}
# \kanji{足}{\strut ソク \strut}{\strut foot, \strut leg, \strut suf\-fi\-cient \strut}
# \kanji{赤}{\strut あか \strut}{\strut red \strut}
# \end{center}
# \section*{Level 5}
# \begin{center}
# \kanji{音}{\strut オン \strut}{\strut sound \strut}
# \kanji{草}{\strut くさ \strut}{\strut grass, \strut weed \strut}
# \kanji{青}{\strut セイ, \strut ショウ \strut}{\strut blue \strut}
# \kanji{雨}{\strut あめ, \strut あま \strut}{\strut rain \strut}
# \kanji{金}{\strut キン \strut}{\strut gold \strut}
# \kanji{空}{\strut クウ \strut}{\strut sky \strut}
# \kanji{林}{\strut はやし \strut}{\strut for\-est, \strut woods \strut}
# \kanji{学}{\strut ガク \strut}{\strut study, \strut learn, \strut learn\-ing \strut}
# \kanji{麦}{\strut むぎ \strut}{\strut wheat \strut}
# \kanji{里}{\strut さと \strut}{\strut home\- vil\-lage, \strut home\- \-town, \strut home\-town \strut}
# \kanji{近}{\strut キン, \strut コン \strut}{\strut near, \strut close \strut}
# \kanji{走}{\strut ソウ \strut}{\strut run \strut}
# \kanji{谷}{\strut たに \strut}{\strut val\-ley \strut}
# \kanji{言}{\strut ゲン, \strut ゴン \strut}{\strut say \strut}
# \kanji{角}{\strut カク \strut}{\strut an\-gle, \strut cor\-ner \strut}
# \kanji{社}{\strut シャ \strut}{\strut com\-pa\-ny \strut}
# \kanji{来}{\strut ライ \strut}{\strut come, \strut next \strut}
# \kanji{形}{\strut ケイ \strut}{\strut shape, \strut ap\-pear\-ance, \strut form \strut}
# \kanji{弟}{\strut ダイ, \strut デ, \strut テイ \strut}{\strut younger broth\-er, \strut lit\-tle broth\-er \strut}
# \kanji{売}{\strut う \strut}{\strut sell \strut}
# \kanji{声}{\strut こえ \strut}{\strut voice \strut}
# \kanji{図}{\strut ズ, \strut ト \strut}{\strut di\-a\-gram \strut}
# \kanji{作}{\strut サク, \strut サ \strut}{\strut make \strut}
# \kanji{体}{\strut タイ \strut}{\strut body \strut}
# \kanji{何}{\strut なに, \strut なん \strut}{\strut what \strut}
# \kanji{西}{\strut セイ, \strut サイ \strut}{\strut west \strut}
# \kanji{行}{\strut コウ, \strut ギョウ \strut}{\strut go \strut}
# \kanji{色}{\strut いろ \strut}{\strut col\-or, \strut colour \strut}
# \kanji{自}{\strut ジ, \strut シ \strut}{\strut self \strut}
# \kanji{肉}{\strut ニク \strut}{\strut meat \strut}
# \kanji{考}{\strut かんが \strut}{\strut think, \strut con\-sid\-er \strut}
# \kanji{羽}{\strut はね, \strut は \strut}{\strut feath\-er, \strut feath\-ers, \strut wing, \strut wings \strut}
# \kanji{米}{\strut ベイ, \strut マイ \strut}{\strut rice, \strut amer\-i\-ca \strut}
# \kanji{池}{\strut いけ \strut}{\strut pond \strut}
# \kanji{毎}{\strut マイ \strut}{\strut every \strut}
# \kanji{当}{\strut トウ \strut}{\strut cor\-rect, \strut right, \strut suc\-cess \strut}
# \kanji{多}{\strut タ \strut}{\strut many, \strut much, \strut lot\-s of \strut}
# \kanji{回}{\strut カイ \strut}{\strut times, \strut re\-volve \strut}
# \kanji{同}{\strut ドウ \strut}{\strut same \strut}
# \kanji{光}{\strut コウ \strut}{\strut sun\-light, \strut light \strut}
# \kanji{会}{\strut カイ \strut}{\strut meet \strut}
# \kanji{交}{\strut コウ \strut}{\strut mix \strut}
# \end{center}
# \section*{Level 6}
# \begin{center}
# \kanji{亡}{\strut ボウ \strut}{\strut de\-ceased, \strut death \strut}
# \kanji{首}{\strut くび \strut}{\strut neck \strut}
# \kanji{食}{\strut ショク \strut}{\strut eat, \strut meal \strut}
# \kanji{茶}{\strut チャ, \strut サ \strut}{\strut tea \strut}
# \kanji{科}{\strut カ \strut}{\strut sci\-ence \strut}
# \kanji{点}{\strut テン \strut}{\strut point, \strut dec\-i\-mal, \strut dec\-i\-mal \-point \strut}
# \kanji{海}{\strut カイ \strut}{\strut sea, \strut ocean \strut}
# \kanji{活}{\strut カツ \strut}{\strut live\-ly \strut}
# \kanji{星}{\strut ほし \strut}{\strut star \strut}
# \kanji{思}{\strut シ \strut}{\strut think, \strut thought \strut}
# \kanji{後}{\strut ゴ, \strut コウ \strut}{\strut be\-hind, \strut af\-ter, \strut back, \strut rear \strut}
# \kanji{室}{\strut シツ \strut}{\strut room \strut}
# \kanji{南}{\strut ナン \strut}{\strut south \strut}
# \kanji{前}{\strut ゼン \strut}{\strut front, \strut be\-fore \strut}
# \kanji{長}{\strut チョウ \strut}{\strut long, \strut leader \strut}
# \kanji{知}{\strut チ \strut}{\strut know \strut}
# \kanji{直}{\strut チョク, \strut ジキ \strut}{\strut fix, \strut di\-rect \strut}
# \kanji{画}{\strut ガ, \strut カク \strut}{\strut draw\-ing, \strut paint\-ing \strut}
# \kanji{歩}{\strut ホ \strut}{\strut walk \strut}
# \kanji{東}{\strut トウ \strut}{\strut east \strut}
# \kanji{明}{\strut メイ \strut}{\strut bright \strut}
# \kanji{店}{\strut テン \strut}{\strut shop, \strut store \strut}
# \kanji{姉}{\strut シ \strut}{\strut old\-er \-sis\-ter, \strut big \-sis\-ter, \strut el\-der \-sis\-ter \strut}
# \kanji{妹}{\strut マイ \strut}{\strut younger \-sis\-ter, \strut lit\-tle \-sis\-ter \strut}
# \kanji{夜}{\strut ヤ \strut}{\strut night, \strut evening \strut}
# \kanji{国}{\strut コク \strut}{\strut coun\-try \strut}
# \kanji{京}{\strut キョウ \strut}{\strut cap\-i\-tal \strut}
# \kanji{血}{\strut ケツ \strut}{\strut blood \strut}
# \kanji{羊}{\strut ヨウ \strut}{\strut sheep \strut}
# \kanji{死}{\strut シ \strut}{\strut death \strut}
# \kanji{次}{\strut ジ \strut}{\strut next \strut}
# \kanji{有}{\strut ユウ, \strut ウ \strut}{\strut have \strut}
# \kanji{曲}{\strut キョク \strut}{\strut mu\-sic, \strut bend \strut}
# \kanji{州}{\strut シュウ \strut}{\strut state, \strut province, \strut coun\-ty \strut}
# \kanji{安}{\strut アン \strut}{\strut re\-lax, \strut cheap \strut}
# \kanji{向}{\strut コウ \strut}{\strut yon\-der, \strut fac\-ing \strut}
# \kanji{全}{\strut ゼン \strut}{\strut all, \strut whole \strut}
# \kanji{両}{\strut リョウ \strut}{\strut both \strut}
# \kanji{地}{\strut チ, \strut ジ \strut}{\strut earth, \strut ground \strut}
# \kanji{化}{\strut カ \strut}{\strut change \strut}
# \end{center}
# \section*{Level 7}
# \begin{center}
# \kanji{風}{\strut フウ \strut}{\strut wind, \strut style \strut}
# \kanji{黒}{\strut コク \strut}{\strut black \strut}
# \kanji{黄}{\strut き \strut}{\strut yel\-low \strut}
# \kanji{鳥}{\strut チョウ \strut}{\strut bird \strut}
# \kanji{魚}{\strut ギョ \strut}{\strut fish \strut}
# \kanji{雪}{\strut ゆき \strut}{\strut snow \strut}
# \kanji{週}{\strut シュウ \strut}{\strut week \strut}
# \kanji{船}{\strut セン \strut}{\strut boat, \strut ship \strut}
# \kanji{組}{\strut ソ \strut}{\strut group, \strut as\-so\-ci\-a\-tion, \strut team \strut}
# \kanji{理}{\strut リ \strut}{\strut rea\-son \strut}
# \kanji{教}{\strut キョウ \strut}{\strut teach \strut}
# \kanji{強}{\strut キョウ \strut}{\strut strong, \strut strength \strut}
# \kanji{高}{\strut コウ \strut}{\strut tall, \strut ex\-pen\-sive, \strut high \strut}
# \kanji{通}{\strut ツウ \strut}{\strut pass through \strut}
# \kanji{記}{\strut キ \strut}{\strut write \-down, \strut record \strut}
# \kanji{紙}{\strut かみ \strut}{\strut pa\-per \strut}
# \kanji{時}{\strut ジ \strut}{\strut time, \strut o'\-clock, \strut hour \strut}
# \kanji{弱}{\strut ジャク \strut}{\strut weak \strut}
# \kanji{家}{\strut カ, \strut ケ \strut}{\strut house, \strut home \strut}
# \kanji{夏}{\strut なつ \strut}{\strut sum\-mer \strut}
# \kanji{校}{\strut コウ \strut}{\strut school \strut}
# \kanji{末}{\strut マツ \strut}{\strut end \strut}
# \kanji{未}{\strut ミ \strut}{\strut not yet \strut}
# \kanji{必}{\strut ヒツ \strut}{\strut cer\-tain \strut}
# \kanji{失}{\strut シツ \strut}{\strut fault \strut}
# \kanji{以}{\strut イ \strut}{\strut by mean\-s of, \strut by the mean\-s of, \strut by way of, \strut by the way of \strut}
# \kanji{付}{\strut つ \strut}{\strut at\-tach \strut}
# \kanji{辺}{\strut ヘン \strut}{\strut area \strut}
# \kanji{民}{\strut ミン \strut}{\strut peo\-ples, \strut peo\-ple, \strut na\-tion \strut}
# \kanji{札}{\strut サツ \strut}{\strut bill, \strut tag, \strut la\-bel, \strut note \strut}
# \kanji{由}{\strut ユウ \strut}{\strut rea\-son \strut}
# \kanji{氏}{\strut シ \strut}{\strut fam\-i\-ly \-name, \strut last \-name, \strut sur\-name \strut}
# \kanji{欠}{\strut ケツ \strut}{\strut lack \strut}
# \end{center}
# \section*{Level 8}
# \begin{center}
# \kanji{反}{\strut ハン \strut}{\strut anti \strut}
# \kanji{合}{\strut あ, \strut あい \strut}{\strut suit, \strut fit, \strut join \strut}
# \kanji{所}{\strut ショ \strut}{\strut place \strut}
# \kanji{電}{\strut デン \strut}{\strut elec\-tric\-i\-ty \strut}
# \kanji{話}{\strut ワ \strut}{\strut talk, \strut speak \strut}
# \kanji{楽}{\strut ラク, \strut ガク \strut}{\strut com\-fort, \strut ease, \strut plea\-sure \strut}
# \kanji{数}{\strut スウ \strut}{\strut count, \strut num\-ber, \strut amount \strut}
# \kanji{雲}{\strut くも \strut}{\strut cloud \strut}
# \kanji{間}{\strut カン, \strut ケン \strut}{\strut in\-ter\-val, \strut in\-ter\-val of \-time, \strut time in\-ter\-val \strut}
# \kanji{道}{\strut ドウ \strut}{\strut road, \strut street, \strut path, \strut way \strut}
# \kanji{買}{\strut か \strut}{\strut buy \strut}
# \kanji{絵}{\strut エ \strut}{\strut draw\-ing, \strut paint\-ing \strut}
# \kanji{答}{\strut こた \strut}{\strut an\-swer, \strut re\-sponse, \strut re\-ply \strut}
# \kanji{番}{\strut バン \strut}{\strut num\-ber in a series, \strut turn, \strut or\-di\-nal num\-ber \strut}
# \kanji{朝}{\strut あさ \strut}{\strut morn\-ing \strut}
# \kanji{場}{\strut ば \strut}{\strut lo\-ca\-tion, \strut place \strut}
# \kanji{森}{\strut もり \strut}{\strut for\-est, \strut woods \strut}
# \kanji{馬}{\strut バ \strut}{\strut horse \strut}
# \kanji{研}{\strut ケン \strut}{\strut sharp\-en \strut}
# \kanji{者}{\strut シャ \strut}{\strut some\-one, \strut some\-body \strut}
# \kanji{身}{\strut シン \strut}{\strut some\-body, \strut some\-one, \strut body \strut}
# \kanji{究}{\strut キュウ \strut}{\strut re\-search \strut}
# \kanji{決}{\strut ケツ \strut}{\strut de\-cide, \strut de\-ci\-sion \strut}
# \kanji{投}{\strut な \strut}{\strut throw \strut}
# \kanji{役}{\strut ヤク \strut}{\strut ser\-vice, \strut duty \strut}
# \kanji{局}{\strut キョク \strut}{\strut bu\-reau, \strut de\-part\-ment \strut}
# \kanji{対}{\strut タイ \strut}{\strut ver\-sus, \strut op\-po\-site \strut}
# \kanji{君}{\strut クン \strut}{\strut bud\-dy \strut}
# \kanji{医}{\strut イ \strut}{\strut med\-i\-cine \strut}
# \kanji{助}{\strut ジョ \strut}{\strut help \strut}
# \kanji{住}{\strut ジュウ \strut}{\strut dwelling, \strut re\-side, \strut dwell \strut}
# \kanji{支}{\strut シ \strut}{\strut sup\-port, \strut branch \strut}
# \end{center}
# \section*{Level 9}
# \begin{center}
# \kanji{度}{\strut ド, \strut タク \strut}{\strut de\-grees, \strut oc\-cur\-rence \strut}
# \kanji{返}{\strut ヘン \strut}{\strut re\-turn \strut}
# \kanji{新}{\strut シン \strut}{\strut new \strut}
# \kanji{予}{\strut ヨ \strut}{\strut be\-fore\-hand \strut}
# \kanji{仮}{\strut カ \strut}{\strut tem\-po\-rary \strut}
# \kanji{勝}{\strut ショウ \strut}{\strut win \strut}
# \kanji{要}{\strut ヨウ \strut}{\strut need \strut}
# \kanji{談}{\strut ダン \strut}{\strut dis\-cuss \strut}
# \kanji{重}{\strut ジュウ, \strut チョウ \strut}{\strut heavy \strut}
# \kanji{送}{\strut ソウ \strut}{\strut send \strut}
# \kanji{負}{\strut フ \strut}{\strut lose \strut}
# \kanji{美}{\strut ビ, \strut ミ \strut}{\strut beau\-ty, \strut beau\-ti\-ful \strut}
# \kanji{県}{\strut ケン \strut}{\strut pre\-fec\-ture \strut}
# \kanji{相}{\strut ソウ, \strut ショウ \strut}{\strut mu\-tu\-al \strut}
# \kanji{発}{\strut ハツ \strut}{\strut de\-par\-ture \strut}
# \kanji{界}{\strut カイ \strut}{\strut world \strut}
# \kanji{持}{\strut も \strut}{\strut hold \strut}
# \kanji{待}{\strut ま \strut}{\strut wait \strut}
# \kanji{屋}{\strut や \strut}{\strut roof, \strut shop, \strut store \strut}
# \kanji{客}{\strut キャク \strut}{\strut guest \strut}
# \kanji{乗}{\strut の \strut}{\strut ride \strut}
# \kanji{部}{\strut ブ \strut}{\strut part, \strut de\-part\-ment, \strut club \strut}
# \kanji{表}{\strut ヒョウ \strut}{\strut ex\-press \strut}
# \kanji{苦}{\strut ク \strut}{\strut suf\-fer\-ing \strut}
# \kanji{物}{\strut もの \strut}{\strut thing \strut}
# \kanji{泳}{\strut およ \strut}{\strut swim \strut}
# \kanji{服}{\strut フク \strut}{\strut clothes, \strut cloth\-ing \strut}
# \kanji{実}{\strut ジツ \strut}{\strut truth, \strut re\-al\-i\-ty \strut}
# \kanji{定}{\strut テイ, \strut ジョウ \strut}{\strut de\-ter\-mine \strut}
# \kanji{始}{\strut はじ \strut}{\strut be\-gin, \strut start \strut}
# \kanji{和}{\strut ワ, \strut オ \strut}{\strut peace, \strut japan\-ese style \strut}
# \kanji{受}{\strut う \strut}{\strut ac\-cept, \strut re\-ceive \strut}
# \kanji{具}{\strut グ \strut}{\strut tool \strut}
# \kanji{使}{\strut シ \strut}{\strut use \strut}
# \kanji{事}{\strut ジ \strut}{\strut ac\-tion, \strut mat\-ter, \strut thing \strut}
# \end{center}

# %%
def format_vocab(row):
    kanji = row.character
    reading = row.kana.split(",")[0]
    meaning = strutify(row.meaning)
    return rf"\vocab{{{kanji}}}{{{reading}}}{{{meaning}}}"

# %%
with open("tex/output.tex", "w") as file:
    for level in range(1, 10 + 1):
        print(rf"\section*{{Level {level}}}", file=file)
        print(r"\begin{flushleft}", file=file)
        print(str.join("\n", [format_kanji(row) for row in kanji.query(f"level == {level}").itertuples()]), file=file)
        print(r"\end{flushleft}", file=file)
        print(r"\begin{flushleft}", file=file)
        print(str.join("\n", [format_vocab(row) for row in vocabulary.query(f"level == {level}").itertuples()]), file=file)
        print(r"\end{flushleft}", file=file)

# %%
kanji["reading"] = ""

# %%
kanji.loc[kanji.important_reading == "kunyomi", "reading"] = kanji.loc[kanji.important_reading == "kunyomi", "kunyomi"]
kanji.loc[kanji.important_reading == "onyomi", "reading"] = kanji.loc[kanji.important_reading == "onyomi", "onyomi"]
kanji.loc[kanji.important_reading == "nanori", "reading"] = kanji.loc[kanji.important_reading == "nanori", "nanori"]

# %%
kanji["reading_length"] = kanji.reading.map(len)

# %%
kanji.sort_values("reading_length", ascending=False)
# Out:
#       level character      kunyomi        onyomi nanori important_reading  \
# 222      54         荘     あごそ, ほうき  そう, しょう, ちゃん   None            onyomi
# 1983      4         平      たいら, ひら  へい, ひょう, びょう   None            onyomi
# 157      55         龍           たつ  りゅう, りょう, ろう   None            onyomi
# 1487     29         請         う, こ   せい, しん, しょう   None            onyomi
# 39       59         梓  あずさ                     し   None           kunyomi
# 217      54         酬           むく   しゅう, しゅ, とう   None            onyomi
# 1517     28         清           きよ   せい, しょう, しん      し            onyomi
# 96       58         殻       から, がら    かく, こく, ばい   None            onyomi
# 1918      5         弟         おとうと     だい, で, てい   None            onyomi
# 1937      3         分            わ     ぶん, ふん, ぶ   None            onyomi
# 224      53         莉         None     り, れい, らい   None            onyomi
# 739      37         抱    だ, かか, いだ            ほう   None           kunyomi
# 25       60         湧            わ     ゆう, ゆ, よう   None            onyomi
# 67       59         雌    めす, め, めん             し   None           kunyomi
# 754      37         旬         None      しゅん, じゅん   None            onyomi
# 66       59         堪     た, こた, こ        かん, たん   None           kunyomi
# 556      43         柔           やわ      じゅう, にゅう   None            onyomi
# 1101     24         祝           いわ      しゅく, しゅう   None            onyomi
# 1672      9         重    おも, かさ, え      じゅう, ちょう   None            onyomi
# 302      51         苗       なえ, なわ      みょう, びょう   None            onyomi
# 80       58         暁     あかつき, さと      きょう, ぎょう   None           kunyomi
# 140      56         窮           きわ      きゅう, きょう   None            onyomi
# 964      32         興         None       きょう, こう   None            onyomi
# 210      54         粛          つつし       しゅく, すく   None            onyomi
# 256      53         浄           きよ       じょう, せい   None            onyomi
# 1818      2         丁         None       ちょう, てい   None            onyomi
# 76       58         瑞      みず, しるし        すい, ずい   None           kunyomi
# 215      54         卸      おろし, おろ            しゃ   None           kunyomi
# 1262     36         姓         None       せい, しょう   None            onyomi
# 616      41         畑      はたけ, はた          None   None           kunyomi
# ...     ...       ...          ...           ...    ...               ...
# 812      49         尼           あま             に   None            onyomi
# 825      36         舞        まい, ま             ぶ   None            onyomi
# 1674      9         負         ま, お             ふ   None            onyomi
# 826      36         維         None             い   None            onyomi
# 1695      9         受            う            じゅ   None           kunyomi
# 842      36         伸            の            しん   None           kunyomi
# 1708      8         絵         None             え   None            onyomi
# 1707      8         買            か            ばい   None           kunyomi
# 377      48         餓            う             が   None            onyomi
# 378      48         飢            う             き   None            onyomi
# 1266     19         布           ぬの             ふ   None            onyomi
# 839      36         奈         None             な   None            onyomi
# 1701      8         話      はな, はなし             わ   None            onyomi
# 1698      9         事       こと, つか             じ   None            onyomi
# 1697      9         使           つか             し   None            onyomi
# 1696      9         具         None             ぐ   None            onyomi
# 384      48         貼            は           ちょう   None           kunyomi
# 1279     18         可         None             か   None            onyomi
# 386      48         蚊            か          None   None           kunyomi
# 1271     19         加           くわ             か   None            onyomi
# 1687      9         苦       くる, にが             く   None            onyomi
# 1275     18         句         None             く   None            onyomi
# 1685      9         部            へ             ぶ   None            onyomi
# 1684      9         乗            の           じょう   None           kunyomi
# 1682      9         屋            や            おく   None           kunyomi
# 1681      9         待            ま            たい   None           kunyomi
# 1680      9         持            も             じ   None           kunyomi
# 830      36         津            つ            しん   None           kunyomi
# 399      47         扉          とびら             ひ   None            onyomi
# 1252     19         宇         None             う   None            onyomi
#
#                                  meaning       reading  reading_length
# 222                                villa  そう, しょう, ちゃん              12
# 1983                         flat, peace  へい, ひょう, びょう              12
# 157                     imperial, dragon  りゅう, りょう, ろう              12
# 1487                             request   せい, しん, しょう              11
# 39                            wood block   あずさ                      11
# 217                                repay   しゅう, しゅ, とう              11
# 1517                                pure   せい, しょう, しん              11
# 96                           husk, shell    かく, こく, ばい              10
# 1918     younger brother, little brother     だい, で, てい               9
# 1937  part, minute, separate, understand     ぶん, ふん, ぶ               9
# 224                              jasmine     り, れい, らい               9
# 739                                  hug     だ, かか, いだ               9
# 25                            well, boil     ゆう, ゆ, よう               9
# 67                                female     めす, め, めん               9
# 754     in season, time of month, season      しゅん, じゅん               8
# 66                                endure      た, こた, こ               8
# 556                               gentle      じゅう, にゅう               8
# 1101                           celebrate      しゅく, しゅう               8
# 1672                               heavy      じゅう, ちょう               8
# 302                    seedling, sapling      みょう, びょう               8
# 80                                  dawn      あかつき, さと               8
# 140                            destitute      きゅう, きょう               8
# 964                             interest       きょう, こう               7
# 210                               solemn       しゅく, すく               7
# 256                      cleanse, purify       じょう, せい               7
# 1818                        street, ward       ちょう, てい               7
# 76                       congratulations       みず, しるし               7
# 215                            wholesale       おろし, おろ               7
# 1262                surname, family name       せい, しょう               7
# 616                                field       はたけ, はた               7
# ...                                  ...           ...             ...
# 812                                  nun             に               1
# 825                                dance             ぶ               1
# 1674                                lose             ふ               1
# 826                             maintain             い               1
# 1695                     accept, receive             う               1
# 842                              stretch             の               1
# 1708                   drawing, painting             え               1
# 1707                                 buy             か               1
# 377                               starve             が               1
# 378                               starve             き               1
# 1266                               cloth             ふ               1
# 839                                 nara             な               1
# 1701                         talk, speak             わ               1
# 1698               action, matter, thing             じ               1
# 1697                                 use             し               1
# 1696                                tool             ぐ               1
# 384                                paste             は               1
# 1279                            possible             か               1
# 386                             mosquito             か               1
# 1271                                 add             か               1
# 1687                           suffering             く               1
# 1275                   paragraph, phrase             く               1
# 1685              part, department, club             ぶ               1
# 1684                                ride             の               1
# 1682                   roof, shop, store             や               1
# 1681                                wait             ま               1
# 1680                                hold             も               1
# 830                                haven             つ               1
# 399                           front door             ひ               1
# 1252                         outer space             う               1
#
# [2027 rows x 9 columns]
